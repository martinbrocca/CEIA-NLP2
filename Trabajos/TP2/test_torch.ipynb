# %%
import torch
print(torch.backends.mps.is_available())
print(torch.backends.mps.is_built())
# Out:
# True
# True

# %%
#read resumes from a directory using python-docx
import os
from docx import Document
resumes = []
resumes_dir = "resumes"
for filename in os.listdir(resumes_dir):
    if filename.endswith(".docx"):
        doc = Document(os.path.join(resumes_dir, filename))
        text = "\n".join([para.text for para in doc.paragraphs])
        resumes.append(text)
print(f"Loaded {len(resumes)} resumes.")
# Out:
# Loaded 1 resumes.

# %%
#display first 500 characters of the first resume
print(resumes[0][:1500])
# Out:
# Highly skilled and experienced Argentine-Italian IT professional with a strong technical background and over 7 years of leadership experience. Proven track record of facilitating discussions with senior leadership, addressing technical trade-offs, implementing best practices, and mitigating risks. Thrives in large, dynamic, and culturally diverse environments. Seeking a challenging role in an adaptable and forward-thinking company, where I can leverage my expertise to drive innovation, deliver exceptional solutions, and contribute to the company's growth and success.
#
# Work History
# 2022 - Present
# Solution Architect, Data & Analytics / ExxonMobil, Houston, TX
# Shape strategic vision and roadmaps for data and analytics technologies within the Unconventional Upstream domain. Define future states and spearhead innovative solutions to optimize operations and decision-making processes.
# Collaborate closely with cross-functional teams, including product owners, data engineers, and data scientists, to architect and deploy comprehensive data solutions and advanced analytics capabilities.
# Establish and communicate architectural guidelines, best practices, and standards, ensuring alignment and coherence across all data and analytics initiatives within the organization.
# Provide decisive technical leadership and guidance throughout the lifecycle of data and analytics projects, ensuring successful implementation and delivery.
# 2022 - 2023
# Solution Architect, IoT & Digital Twin / ExxonMobil, H

# %%
print(resumes)
# Out:
# ["Highly skilled and experienced Argentine-Italian IT professional with a strong technical background and over 7 years of leadership experience. Proven track record of facilitating discussions with senior leadership, addressing technical trade-offs, implementing best practices, and mitigating risks. Thrives in large, dynamic, and culturally diverse environments. Seeking a challenging role in an adaptable and forward-thinking company, where I can leverage my expertise to drive innovation, deliver exceptional solutions, and contribute to the company's growth and success. \n\nWork History\n2022 - Present\nSolution Architect, Data & Analytics / ExxonMobil, Houston, TX\nShape strategic vision and roadmaps for data and analytics technologies within the Unconventional Upstream domain. Define future states and spearhead innovative solutions to optimize operations and decision-making processes.\nCollaborate closely with cross-functional teams, including product owners, data engineers, and data scientists, to architect and deploy comprehensive data solutions and advanced analytics capabilities.\nEstablish and communicate architectural guidelines, best practices, and standards, ensuring alignment and coherence across all data and analytics initiatives within the organization.\nProvide decisive technical leadership and guidance throughout the lifecycle of data and analytics projects, ensuring successful implementation and delivery.\n2022 - 2023\nSolution Architect, IoT & Digital Twin / ExxonMobil, Houston, TX\nServe as a liaison among different internal organizations to identify critical data and gather requirements for IoT and Digital Twin initiatives. Lead the company towards a transformative journey of digital immersive technologies, aiming to reduce operational costs and improve turnaround times. Assess end-to-end architecture and solutions for IoT and Digital Twin projects, considering scalability, security, and data integration requirements. \nEvaluate and recommend appropriate technologies, platforms, and tools for implementing IoT and Digital Twin solutions. \nEngage with external vendors and partners to explore collaboration opportunities and leverage their expertise for solution development.\n2019 – 2022\nSolution Architect, Observability/ ExxonMobil, Houston, TX\nDesigned and implemented a unified observability platform for the overall IT systems, enhancing data accessibility, reducing silos, and enabling informed decision-making and automations.\nResponsible for Cloud Monitoring strategy, developing standards and best practices for Cloud Monitoring.\nMentor and develop future technical experts.\n2018 – 2019\nProduct Manager, Internet Hosting and DMZ / ExxonMobil, Buenos Aires, Argentina \nManaging a diverse customer set that includes all externally accessed (eBusiness and corporate) applications and services to interconnect our company with remote employees or third-party customers (IPSec and SSL VPNs). \nFunctional Supervision for 4 teams globally distributed (40 dev-team members) providing engineering and escalation support for all environments.  \n2017 – 2018\nInternet Services Delivery Lead/ ExxonMobil, Buenos Aires, Argentina \nCross-Functional leadership on design, implementation and change control over Company’s DMZs and Internet related services.  Coordination of DMZ related Project Portfolio ensuring services continuity and value delivery. SWATs teams and War Rooms coordination during major operational incidents.\n2014 – 2017\nProject Manager/ ExxonMobil, Buenos Aires, Argentina \nInfrastructure Project Manager, leading several projects including: \n- VMWare VCM Replacement: $0,8M project to replace VCM compliance tool with compatible tool-set  \n- Linux Server Provision Automation: $1.5M project to design and develop automation infrastructure and server provisioning \n- Next Gen DMZ implementation: $5M project to design and build the corporation’s DMZs leveraging virtualization and modern platforms \n\n2011 – 2014\nT ...

# %%
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer

#leer la clave API desde variables del archivo .env
import os
from dotenv import load_dotenv

from langchain_text_splitters import RecursiveCharacterTextSplitter



load_dotenv()
pinecone_api_key = os.getenv("PINECONE_API_KEY")

# 1. Inicializar Pinecone
pc = Pinecone(api_key=pinecone_api_key)

# 2. Crear un índice (solo la primera vez)
index_name = "resume-embeddings-2"

# Verificar si el índice existe
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=384,  # depende del modelo de embeddings
        metric="cosine",  # o "euclidean", "dotproduct"
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# 3. Conectar al índice
index = pc.Index(index_name)

# %%
chunk_size = 500
chunk_overlap = 50

# %%
# 4. Generar embeddings del texto
model = SentenceTransformer('all-MiniLM-L6-v2')  # 384 dimensiones
#generar el loop para embedir multiples textos

text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
texts = text_splitter.split_text(resumes[0])
print(texts)
# Out:
# ['Highly skilled and experienced Argentine-Italian IT professional with a strong technical background and over 7 years of leadership experience. Proven track record of facilitating discussions with senior leadership, addressing technical trade-offs, implementing best practices, and mitigating risks. Thrives in large, dynamic, and culturally diverse environments. Seeking a challenging role in an adaptable and forward-thinking company, where I can leverage my expertise to drive innovation, deliver', "my expertise to drive innovation, deliver exceptional solutions, and contribute to the company's growth and success.", 'Work History\n2022 - Present\nSolution Architect, Data & Analytics / ExxonMobil, Houston, TX\nShape strategic vision and roadmaps for data and analytics technologies within the Unconventional Upstream domain. Define future states and spearhead innovative solutions to optimize operations and decision-making processes.', 'Collaborate closely with cross-functional teams, including product owners, data engineers, and data scientists, to architect and deploy comprehensive data solutions and advanced analytics capabilities.\nEstablish and communicate architectural guidelines, best practices, and standards, ensuring alignment and coherence across all data and analytics initiatives within the organization.', 'Provide decisive technical leadership and guidance throughout the lifecycle of data and analytics projects, ensuring successful implementation and delivery.\n2022 - 2023\nSolution Architect, IoT & Digital Twin / ExxonMobil, Houston, TX', 'Serve as a liaison among different internal organizations to identify critical data and gather requirements for IoT and Digital Twin initiatives. Lead the company towards a transformative journey of digital immersive technologies, aiming to reduce operational costs and improve turnaround times. Assess end-to-end architecture and solutions for IoT and Digital Twin projects, considering scalability, security, and data integration requirements.', 'Evaluate and recommend appropriate technologies, platforms, and tools for implementing IoT and Digital Twin solutions. \nEngage with external vendors and partners to explore collaboration opportunities and leverage their expertise for solution development.\n2019 – 2022\nSolution Architect, Observability/ ExxonMobil, Houston, TX', 'Designed and implemented a unified observability platform for the overall IT systems, enhancing data accessibility, reducing silos, and enabling informed decision-making and automations.\nResponsible for Cloud Monitoring strategy, developing standards and best practices for Cloud Monitoring.\nMentor and develop future technical experts.\n2018 – 2019\nProduct Manager, Internet Hosting and DMZ / ExxonMobil, Buenos Aires, Argentina', 'Managing a diverse customer set that includes all externally accessed (eBusiness and corporate) applications and services to interconnect our company with remote employees or third-party customers (IPSec and SSL VPNs). \nFunctional Supervision for 4 teams globally distributed (40 dev-team members) providing engineering and escalation support for all environments.  \n2017 – 2018\nInternet Services Delivery Lead/ ExxonMobil, Buenos Aires, Argentina', 'Cross-Functional leadership on design, implementation and change control over Company’s DMZs and Internet related services.  Coordination of DMZ related Project Portfolio ensuring services continuity and value delivery. SWATs teams and War Rooms coordination during major operational incidents.\n2014 – 2017\nProject Manager/ ExxonMobil, Buenos Aires, Argentina \nInfrastructure Project Manager, leading several projects including:', '- VMWare VCM Replacement: $0,8M project to replace VCM compliance tool with compatible tool-set  \n- Linux Server Provision Automation: $1.5M project to design and develop automation infrastructure and server provisioning \n- Next Gen DMZ implementation: $5M project to design and build the corporation’s DMZs leveragin ...

# %%
# 6. Para múltiples textos (batch)
embeddings = model.encode(texts)

vectors_to_upsert = [
    {
        "id": f"doc-{i}",
        "values": emb.tolist(),
        "metadata": {"text": txt}
    }
    for i, (txt, emb) in enumerate(zip(texts, embeddings))
]

index.upsert(vectors=vectors_to_upsert)
# Out:
# UpsertResponse(upserted_count=15, _response_info={'raw_headers': {'date': 'Wed, 26 Nov 2025 00:32:03 GMT', 'content-type': 'application/json', 'content-length': '20', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '28724', 'x-pinecone-request-latency-ms': '602', 'x-pinecone-request-id': '6557173867556376823', 'x-envoy-upstream-service-time': '454', 'grpc-status': '0', 'server': 'envoy'}})

# %%
# 7. Buscar textos similares
query_text = "What is the education?"
query_embedding = model.encode(query_text).tolist()

results = index.query(
    vector=query_embedding,
    top_k=5,
    include_metadata=True
)

for match in results['matches']:
    print(f"Score: {match['score']}, Text: {match['metadata']['text']}")
# Out:
# Score: 0.2211833, Text: Highly skilled and experienced Argentine-Italian IT professional with a strong technical background and over 7 years of leadership experience. Proven track record of facilitating discussions with senior leadership, addressing technical trade-offs, implementing best practices, and mitigating risks. Thrives in large, dynamic, and culturally diverse environments. Seeking a challenging role in an adaptable and forward-thinking company, where I can leverage my expertise to drive innovation, deliver
# Score: 0.187477127, Text: Nov 2004
# Computer Science Engineer / Universidad Nacional del Sur, Bahía Blanca
# Bachelor’s Degree
# Certifications
# SCRUM Product Owner I (PSPO) (2023)
# AWS Solutions Architect Associate (2022)
# AWS Cloud Practitioner (2021)
# TOGAF Foundation (2020)
# SA 4.0 SAFe 4 Agilist (2018)
# RHCE Red Hat Certified Engineer (2010)
# Languages
# English – Bilingual
# Spanish – Native
# French – Elementary
# Score: 0.168674469, Text: my expertise to drive innovation, deliver exceptional solutions, and contribute to the company's growth and success.
# Score: 0.14589119, Text: Provide decisive technical leadership and guidance throughout the lifecycle of data and analytics projects, ensuring successful implementation and delivery.
# 2022 - 2023
# Solution Architect, IoT & Digital Twin / ExxonMobil, Houston, TX
# Score: 0.136584282, Text: Managing a diverse customer set that includes all externally accessed (eBusiness and corporate) applications and services to interconnect our company with remote employees or third-party customers (IPSec and SSL VPNs).
# Functional Supervision for 4 teams globally distributed (40 dev-team members) providing engineering and escalation support for all environments.
# 2017 – 2018
# Internet Services Delivery Lead/ ExxonMobil, Buenos Aires, Argentina

# %%
import langchain
import os
from random import randint
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.prompts import MessagesPlaceholder
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore
from langchain_core.messages import AIMessage, HumanMessage
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
#instantiate Groq for langchain


llm = ChatGroq(
    model="deepseek-r1-distill-llama-70b",
    temperature=0,
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
    # other params...
)
# Incorporate the retriever into a question-answering chain.
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(chat, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

store = {}
def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    print("session_id", session_id)
    return store[session_id]


conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer",
)

def get_completion(usr_txt, session_id):
    conversational_rag_chain.invoke(
        {"input": usr_txt},
        config={
            "configurable": {"session_id": session_id}
        },  # constructs a key "abc123" in `store`.
    )["answer"]
    last_message = store[session_id].messages[-1].content
    return last_message
